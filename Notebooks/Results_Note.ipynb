# %% [markdown]
# ## All Results :Amazon_Bty

# %% [markdown]
# ### hitr_amb

# %%
cols_1 = ['PSI','UpdtPSI','SVD','VAE','iALS','MPOP','RRec']    #'UpdtiALS',
cols_2 = ['PSI_HR','UpdtPSI_HR','SVD_HR','VAE_HR','iALS_HR','MPOP_HR','RRec_HR'] #'UpdtiALS_HR',

AMZB_HitRDF = pd.DataFrame(list(zip(RegPSI_HR_amb,updted_HR_amb,SVD_HitR_amb,VAEHitRat_amb,RTials_HitR_amb,MPOP_Hitr_amb,RRec_HitR_amb)), 
                          columns =cols_1)  #ials_HitR_amb
AMZB_HitRDF
# Out:
#         PSI   UpdtPSI       SVD       VAE      iALS      MPOP      RRec
# 0  0.267932  0.267932  0.297468  0.337553  0.341772  0.151899  0.000000
# 1  0.341801  0.344111  0.321016  0.394919  0.401848  0.205543  0.002309
# 2  0.337634  0.335484  0.318280  0.412903  0.417204  0.191398  0.002151
# 3  0.301255  0.305439  0.317992  0.376569  0.374477  0.182008  0.002092
# 4  0.282427  0.284519  0.309623  0.349372  0.361925  0.140167  0.000000
# 5  0.273622  0.273622  0.299213  0.328740  0.332677  0.145669  0.000000
# 6  0.274510  0.284314  0.333333  0.491830  0.444444  0.062092  0.000000
# 7  0.248748  0.252087  0.273790  0.402337  0.383973  0.190317  0.000000
# 8  0.307836  0.302239  0.335821  0.384328  0.382463  0.190299  0.001866
# 9  0.143529  0.136471  0.190588  0.284706  0.275294  0.141176  0.000000

# %%
AllSteps_10 = list(range(1,11))
makeplot(AllSteps_10,AMZB_HitRDF,y_label="HitRate@10",x_label="Incremental Steps",title="Amazon Beauty HitRate Plot")

# %%
make_boxplot(AMZB_HitRDF,"HitRate@10",'Models','Hitrate Range of Values (Amazon Beauty)')

# %% [markdown]
# ### mrr_amb

# %%
cols_1 = ['PSI','UpdtPSI','SVD','VAE','iALS','MPOP','RRec']    #'UpdtiALS',
COLS_2 = ['PSI_MRR','UpdtPSI_MRR','SVD_MRR','VAE_MRR','iALS_MRR','MPOP_MRR','RRec_MRR']
AMZBMRR_DF = pd.DataFrame(list(zip(Regpsi_MRR_amb,updted_MRR_amb,SVD_MRR_amb,VAE_MRR_amb,RTals_MRR_amb,MPOP_mrr_amb,RRec_mrr_amb)), 
                        columns = cols_1) #als_MRR_amb |'UpdtiALS_MRR',
AMZBMRR_DF
# Out:
#         PSI   UpdtPSI       SVD       VAE      iALS      MPOP      RRec
# 0  0.239419  0.241227  0.257904  0.311623  0.311412  0.066489  0.000000
# 1  0.296410  0.298919  0.265928  0.368231  0.371047  0.088387  0.000770
# 2  0.312709  0.311335  0.282022  0.366621  0.368763  0.085148  0.000430
# 3  0.269700  0.271502  0.277618  0.347652  0.344770  0.075980  0.000299
# 4  0.260157  0.260327  0.276946  0.316760  0.314460  0.059343  0.000000
# 5  0.243877  0.245122  0.262233  0.291176  0.289084  0.061677  0.000000
# 6  0.211119  0.205629  0.252534  0.329006  0.318045  0.027865  0.000000
# 7  0.219799  0.215582  0.238937  0.331425  0.321354  0.057432  0.000000
# 8  0.259858  0.259141  0.271409  0.332130  0.336434  0.062396  0.000187
# 9  0.116059  0.113294  0.152591  0.214192  0.214555  0.035824  0.000000

# %%
makeplot(AllSteps_10,AMZBMRR_DF,y_label="MRR@10",x_label="Incremental Steps",title="Amazon Beauty MRR Plot")

# %%
make_boxplot(AMZBMRR_DF,"MRR@10",'Models','MRR Range of Values (Amazon Beauty)')

# %% [markdown]
# ###cov_amb

# %%
AMZB_cov_DF = pd.DataFrame(list(zip(RegPSI_Cov_amb,updt_COV_amb,svd_cov_amb,VAE_cov_amb,RTals_Cov_amb,Mpop_cov_amb,RRec_cov_amb)), 
                            columns =['PSI_COV','UpdtPSI_COV','SVD_COV','VAE_COV','iALS_COV','MPOP_COV','RRec_COV'])
AMZB_cov_DF        #als_Cov_amb,'UpdtiALS_COV',
# Out:
#     PSI_COV  UpdtPSI_COV   SVD_COV   VAE_COV  iALS_COV  MPOP_COV  RRec_COV
# 0  0.079788     0.079911  0.079788  0.673573  0.516710  0.001233       1.0
# 1  0.080035     0.081884  0.081021  0.703046  0.530892  0.001233       1.0
# 2  0.080281     0.083364  0.079788  0.728573  0.534221  0.001233       1.0
# 3  0.080035     0.084351  0.079295  0.759773  0.541374  0.001233       1.0
# 4  0.079295     0.083981  0.079665  0.797632  0.543470  0.001233       1.0
# 5  0.078925     0.083118  0.079048  0.817487  0.553829  0.001233       1.0
# 6  0.078308     0.083487  0.080035  0.847453  0.565544  0.001233       1.0
# 7  0.078678     0.082008  0.080035  0.852880  0.575163  0.001233       1.0
# 8  0.077568     0.082131  0.079911  0.874584  0.571217  0.001233       1.0
# 9  0.076458     0.082871  0.079418  0.908990  0.574793  0.001233       1.0

# %%
AllSteps_10 = list(range(1,11))
makeplot(AllSteps_10,AMZB_cov_DF,y_label="Coverage",x_label="Incremental Steps",title="Amazon Beauty Coverage Plot")

# %%
##Plot Overlapping
cov_listAMB = [RegPSI_Cov_amb, updt_COV_amb, svd_cov_amb, VAE_cov_amb, RTals_Cov_amb, Mpop_cov_amb, RRec_cov_amb]  #als_Cov_amb
label_list   = [    'PSI',       'Updt_PSI',   'SVD',        'VAE',      'iALS',       'Most_POP',   'Rand_Rec']  #'Updt_iALS', 
num_list = list(range(0,8))
plotoverlapping_2(cov_listAMB,label_list,num_list,title="Amazon Beauty Coverage Plot",
                 x_label="Incremental Steps",y_label="Coverage",size=(12,8),n=11)

# %%
 make_boxplot(AMZB_cov_DF,"Coverage",'Models','Coverage Range of Values (Amazon Beauty)')

# %% [markdown]
# ### Stability

# %%
AMZB_Stability = pd.DataFrame(list(zip(RegPSICorr_amb,updtCorr_amb,svd_corr_amb,VAE_corr_amb,RTiALSCorr_amb,Mpop_corr_amb,RRec_corr_amb)), 
                   columns =['PSI_STBty','UpdtPSI_STBty','SVD_STBty','VAE_STBty','iALS_STBty','MPOP_STBty','RRec_STBty'])
AMZB_Stability   #iALSCorr_amb 'UpdtiALS_STBty',
# Out:
#    PSI_STBty  UpdtPSI_STBty  SVD_STBty  ...  iALS_STBty  MPOP_STBty  RRec_STBty
# 0   0.965020       0.950746   0.727653  ...    0.373198    0.965646    0.000342
# 1   0.965463       0.954120   0.780091  ...    0.374523    1.000000    0.000414
# 2   0.969593       0.946259   0.795077  ...    0.371344    0.965646    0.000372
# 3   0.968605       0.954978   0.777971  ...    0.360062    0.987880    0.000365
# 4   0.952741       0.955831   0.831617  ...    0.368977    1.000000    0.000346
# 5   0.960141       0.950735   0.691071  ...    0.372181    1.000000    0.000392
# 6   0.962292       0.949373   0.740505  ...    0.384222    0.933971    0.000406
# 7   0.943946       0.938544   0.792581  ...    0.362004    0.971158    0.000331
# 8   0.970057       0.962109   0.795507  ...    0.378408    0.906004    0.000339
#
# [9 rows x 7 columns]

# %%
corrSteps = list(range(1,10))
makeplot(corrSteps,AMZB_Stability,y_label="Stability",x_label="Incremental Steps",title="Amazon Beauty Stability Plot")

# %%
##Plot Overlapping

corr_listAMB = [RegPSICorr_amb,updtCorr_amb,svd_corr_amb, VAE_corr_amb, RTiALSCorr_amb, Mpop_corr_amb,RRec_corr_amb] #iALSCorr_amb
label_list   = [    'PSI',       'Updt_PSI',   'SVD',        'VAE',       'iALS',       'Most_POP',   'Rand_Rec']   #'Updt_iALS',
num_list = list(range(0,8))
plotoverlapping_2(corr_listAMB,label_list,num_list,title="Amazon Beauty Stability Plot",
                 x_label="Incremental Steps",y_label="Stability",size=(12,8),n=10)

# %%
make_boxplot(AMZB_Stability,"Stability",'Models','Stability Range of Values (Amazon Beauty)')

# %% [markdown]
# ### Latex Result

# %%
###AMAZON Beauty
plt.subplots(figsize=(18, 5))  

plt.subplot(1, 4, 1)  
plotoverlapping_3(corr_listAMB,label_list,num_list,title="Stability Plot (Allsteps)",
                 x_label="Incremental Steps",y_label=" ",n=10)

plt.subplot(1, 4, 2) 
makeboxplot_2(AMZB_HitRDF," ",'Models','Hitrate(Range of values)')   #AMZBMRR_DF

plt.subplot(1, 4, 3) 
makeboxplot_2(AMZBMRR_DF," ",'Models','MRR (Range of values)')   #AMZBMRR_DF

plt.subplot(1, 4, 4)  
plotoverlapping_3(cov_listAMB,label_list,num_list,title=" Coverage Plot (Allsteps)",
                 x_label="Incremental Steps",y_label="Values",n=11)

#spce between the plots
plt.tight_layout(0.5)
plt.show()

# %% [markdown]
# ## All Results : Amazon_Gmz

# %% [markdown]
# ### hitr_amg

# %%
AllSteps_15 = list(range(1,16))
cols_1 = ['PSI','UpdtPSI','SVD','VAE','iALS','MPOP','RRec']  #'UpdtiALS',
cols_2 = ['PSI_HR','UpdtPSI_HR','SVD_HR','VAE_HR','iALS_HR','MPOP_HR','RRec_HR']  #'UpdtiALS_HR',

AMZGames_HitR_DF = pd.DataFrame(list(zip(RegPSI_HR_amg,updted_HR_amg,SVD_HR_amg,VAEHitRat_amg,RTials_HR_amg,MPOP_HR_amg,RRec_HR_amg)), 
                                     columns=cols_1)  #updtials_HR_amg
AMZGames_HitR_DF
# Out:
#          PSI   UpdtPSI       SVD       VAE      iALS      MPOP      RRec
# 0   0.033697  0.033201  0.050050  0.063429  0.070367  0.006442  0.000991
# 1   0.031818  0.030000  0.044545  0.063182  0.068636  0.006364  0.001364
# 2   0.031768  0.031768  0.046501  0.070442  0.073665  0.004144  0.000460
# 3   0.030303  0.029341  0.059644  0.088504  0.084175  0.003848  0.000962
# 4   0.035424  0.031115  0.054093  0.083293  0.080421  0.004787  0.000000
# 5   0.027830  0.028302  0.048585  0.069811  0.074528  0.002358  0.001887
# 6   0.027515  0.022102  0.042400  0.065404  0.059540  0.007668  0.001353
# 7   0.026733  0.022655  0.033530  0.063888  0.056638  0.005437  0.001812
# 8   0.030942  0.025316  0.045945  0.074543  0.073605  0.005626  0.000938
# 9   0.035007  0.026255  0.048825  0.066789  0.078766  0.007830  0.000000
# 10  0.033613  0.024326  0.040248  0.061477  0.071650  0.007961  0.000442
# 11  0.033393  0.025824  0.056990  0.071238  0.075245  0.012912  0.000000
# ...

# %%
makeplot(AllSteps_15,AMZGames_HitR_DF,y_label="HitRate@10",x_label="Incremental Steps",title="Amazon Games HitRate Plot")

# %%
make_boxplot(AMZGames_HitR_DF,"HitRate@10",'Models','HitRate Range of Values (Amazon Games)')

# %% [markdown]
# ###mrr_amg

# %%
cols_1 = ['PSI','UpdtPSI','SVD','VAE','iALS','MPOP','RRec']  #'UpdtiALS',
cols_2 = ['PSI_MRR', 'UpdtPSI_MRR', 'SVD_MRR','VAE_MRR','iALS_MRR','MPOP_MRR','RRec_MRR']
AMZGames_mrr = pd.DataFrame(list(zip(psi_MRR_amg,updted_MRR_amg,SVD_MRR_amg,VAE_MRR_amg,RTals_MRR_amg,MPOP_mrr_amg,RRec_mrr_amg)), 
                            columns = cols_1)
AMZGames_mrr    #als_MRR_amg,,'UpdtiALS_MRR',
# Out:
#          PSI   UpdtPSI       SVD       VAE      iALS      MPOP      RRec
# 0   0.013398  0.013340  0.022630  0.026573  0.029182  0.001334  0.000578
# 1   0.014141  0.014017  0.024163  0.030148  0.029100  0.002413  0.000338
# 2   0.016565  0.016633  0.022637  0.029686  0.027641  0.000707  0.000153
# 3   0.012617  0.012544  0.028074  0.039665  0.036360  0.000899  0.000168
# 4   0.015305  0.014650  0.026985  0.039017  0.034335  0.001086  0.000000
# 5   0.013355  0.013371  0.028163  0.034911  0.034739  0.000414  0.000218
# 6   0.011169  0.009877  0.019985  0.031014  0.029932  0.001693  0.000182
# 7   0.012022  0.010887  0.016027  0.031454  0.023984  0.000777  0.000374
# 8   0.014899  0.010926  0.021635  0.036950  0.034718  0.001202  0.000586
# 9   0.016974  0.011099  0.023555  0.033214  0.032746  0.001594  0.000000
# 10  0.016547  0.011220  0.020578  0.026606  0.028055  0.001928  0.000063
# 11  0.013888  0.009847  0.026370  0.032199  0.030768  0.002390  0.000000
# ...

# %%
makeplot(AllSteps_15,AMZGames_mrr,y_label="MRR@10",x_label="Incremental Steps",title="Amazon Games MRR Plot")

# %%
make_boxplot(AMZGames_mrr, "MRR@10", 'Models', 'MRR Range of Values(Amazon Games)') #

# %% [markdown]
# ###cov_amg

# %%
AMZGames_covDF = pd.DataFrame(list(zip(PSI_Cov_AMG,updt_COV_AMG,svd_cov_AMG,VAE_cov_AMG,RTals_Cov_AMG,Mpop_cov_AMG,RRec_cov_AMG)), 
                             columns =['PSI_COV','UpdtPSI_COV','SVD_COV','VAE_COV','iALS_COV','MPOP_COV','RRec_COV'])
AMZGames_covDF   #als_Cov_AMG,'UpdtiALS_COV',
# Out:
#      PSI_COV  UpdtPSI_COV   SVD_COV   VAE_COV  iALS_COV  MPOP_COV  RRec_COV
# 0   0.071429     0.071313  0.072179  0.669881  0.191304  0.000577       1.0
# 1   0.071486     0.071486  0.071255  0.685414  0.194422  0.000577       1.0
# 2   0.071486     0.071717  0.072699  0.674443  0.193556  0.000577       1.0
# 3   0.071371     0.071198  0.072295  0.679640  0.194191  0.000577       1.0
# 4   0.071429     0.071371  0.071775  0.683393  0.194595  0.000577       1.0
# 5   0.071544     0.070967  0.070909  0.688532  0.194768  0.000577       1.0
# 6   0.071775     0.071140  0.071082  0.703776  0.193440  0.000577       1.0
# 7   0.071544     0.070678  0.072179  0.698464  0.193498  0.000577       1.0
# 8   0.071255     0.070562  0.071198  0.706895  0.195173  0.000577       1.0
# 9   0.071602     0.071313  0.071833  0.705509  0.194364  0.000577       1.0
# 10  0.071833     0.070620  0.071775  0.710706  0.193671  0.000577       1.0
# ...

# %%
makeplot(AllSteps_15,AMZGames_covDF,y_label="Coverage",x_label="Incremental Steps",title="Amazon Games Coverage Plot")

# %%
##Plot Overlapping

cov_listAMG =  [PSI_Cov_AMG, updt_COV_AMG, svd_cov_AMG, VAE_cov_AMG, RTals_Cov_AMG, Mpop_cov_AMG, RRec_cov_AMG] #als_Cov_AMG,
label_list   = [  'PSI',        'Updt_PSI',   'SVD',        'VAE',      'iALS',     'Most_POP',   'Rand_Rec']   #'Updt_iALS', 
num_list = list(range(0,8))
plotoverlapping_2(cov_listAMG,label_list,num_list,title="Amazon Games Coverage Plot",
                 x_label="Incremental Steps",y_label="Coverage",size=(12,8),n=16)

# %%
make_boxplot(AMZGames_covDF,"Coverage",'Models','Coverage Range of Values (Amazon Games)')

# %% [markdown]
# ###corr_amg

# %%
AMZGamesCORR_DF = pd.DataFrame(list(zip(RegPSICorr_AMG,updtCorr_AMG, svd_corr_AMG, VAE_corr_AMG, RTiALSCorr_AMG,Mpop_corr_AMG,RRec_corr_AMG)), 
                              columns =['PSI_Stby',    'UpdtPSI_Stby','SVD_Stby',   'VAE_Stby', 'iALS_Stby',    'MPOP_Stby','RRec_Stby'])
AMZGamesCORR_DF   #iALSCorr_AMG,  'UpdtiALS_Stby',
# Out:
#     PSI_Stby  UpdtPSI_Stby  SVD_Stby  VAE_Stby  iALS_Stby  MPOP_Stby  RRec_Stby
# 0   0.949130      0.964682  0.788959  0.190492   0.420186   1.000000   0.000189
# 1   0.946882      0.960821  0.820582  0.190099   0.425554   1.000000   0.000155
# 2   0.947942      0.958498  0.794448  0.195370   0.423273   1.000000   0.000170
# 3   0.949640      0.963323  0.781164  0.194213   0.417318   1.000000   0.000187
# 4   0.950456      0.965474  0.806526  0.191071   0.417994   0.944671   0.000165
# 5   0.949879      0.966010  0.804669  0.194580   0.423716   0.933971   0.000187
# 6   0.951746      0.964817  0.806415  0.192188   0.428828   0.949294   0.000188
# 7   0.952383      0.965494  0.815683  0.189972   0.424764   1.000000   0.000170
# 8   0.947885      0.963171  0.797969  0.190509   0.426612   0.912920   0.000189
# 9   0.950463      0.963807  0.782979  0.189535   0.428004   0.867898   0.000157
# 10  0.950541      0.967606  0.818500  0.192249   0.424058   0.875492   0.000184
# ...

# %%
AllSteps_14 = list(range(1,15))
makeplot(AllSteps_14,AMZGamesCORR_DF,y_label="Stability",x_label="Incremental Steps",title="Amazon Games Stability Plot")

# %%
#Plot Overlapping
                              
corr_listAMG = [RegPSICorr_AMG, updtCorr_AMG, svd_corr_AMG, VAE_corr_AMG, RTiALSCorr_AMG, Mpop_corr_AMG, RRec_corr_AMG]   #iALSCorr_AMG,
label_list   = [    'PSI',        'Updt_PSI',   'SVD',        'VAE',        'iALS',        'Most_POP',    'Rand_Rec']     #'Updt_iALS', 
num_list = list(range(0,8))
plotoverlapping_2(corr_listAMG,label_list,num_list,title= "Amazon Games Stability Plot",
                 x_label="Incremental Steps",y_label="Stability",size=(12,8),n=15)

# %%
make_boxplot(AMZGamesCORR_DF,"Stability",'Models','Stability Range of Values (Amazon Games)')

# %% [markdown]
# ### Latex Result

# %%
##Amazon Games
plt.subplots(figsize=(18, 5))  

plt.subplot(1, 4, 1)  
plotoverlapping_3(corr_listAMG,label_list,num_list,title= "AMZG Stability Plot(All steps)",
                 x_label="Incremental Steps",y_label="Stability",n=15)

plt.subplot(1, 4, 2) 
makeboxplot_2(AMZGames_HitR_DF," ",'Models','Hitrate (Range of values)')

plt.subplot(1, 4, 3) 
makeboxplot_2(AMZGames_mrr," ",'Models','MRR (Range of values)')


plt.subplot(1, 4, 4) 
plotoverlapping_3(cov_listAMG,label_list,num_list,title="AMZG Coverage Plot(All steps)",
                 x_label="Incremental Steps",y_label="Coverage",n=16) 


# spce between the plots
plt.tight_layout(0.5)
plt.show()

# %% [markdown]
# ## All Results: MovieLen_1M

# %% [markdown]
# ### hitr_1m

# %%
AllSteps_11 = list(range(1,11))
cols_1 = ['PSI','UpdtPSI','SVD','VAE','iALS','MPOP','RRec']  #'UpdtiALS',
cols_2 = ['PSI_HR','UpdtPSI_HR','SVD_HR','VAE_HR','iALS_HR','MPOP_HR','RRec_HR']  #,'UpdtiALS_HR'

ML1M_HitRDF = pd.DataFrame(list(zip(RegPSI_HR_1M,updted_HR_1M,SVD_HitR_1M,VAEHitRat_ml1,RT_ialsHitR_1M,MPOP_Hitr_1M,RRec_HitR_1M)), 
                          columns =cols_1)  #ials_HitR_1M
ML1M_HitRDF
# Out:
#         PSI   UpdtPSI       SVD       VAE      iALS      MPOP      RRec
# 0  0.072961  0.072961  0.072961  0.064378  0.064378  0.038627  0.000000
# 1  0.086275  0.078431  0.082353  0.070588  0.070588  0.019608  0.000000
# 2  0.083916  0.083916  0.087413  0.108392  0.097902  0.024476  0.000000
# 3  0.067961  0.064725  0.064725  0.080906  0.093851  0.009709  0.000000
# 4  0.047009  0.042735  0.049145  0.047009  0.049145  0.012821  0.004274
# 5  0.047529  0.043726  0.051331  0.051331  0.047529  0.017110  0.005703
# 6  0.054159  0.052224  0.065764  0.065764  0.052224  0.021277  0.003868
# 7  0.046809  0.046809  0.046809  0.053191  0.042553  0.012766  0.004255
# 8  0.061810  0.061810  0.064018  0.066225  0.055188  0.030905  0.000000
# 9  0.055249  0.055249  0.052486  0.049724  0.058011  0.005525  0.002762

# %%
makeplot(AllSteps_11,ML1M_HitRDF,y_label="HitRate@10",x_label="Incremental Steps",title="MovieLen_1M HitRate Plot")

# %%
 make_boxplot(ML1M_HitRDF,"HitRate@10",'Models','HitRate Range of Values (MovieLen_1M)')

# %% [markdown]
# ###mrr_1m

# %%
cols_1 = ['PSI','UpdtPSI','SVD','VAE','iALS','MPOP','RRec']  #'UpdtiALS',
cols_2 = ['PSI_MRR','UpdtPSI_MRR','SVD_MRR','VAE_MRR','iALS_MRR','MPOP_MRR','RRec_MRR']  #'UpdtiALS_MRR',
MRRDF_ML1M = pd.DataFrame(list(zip(Regpsi_MRR_1M,updted_MRR_1M,SVD_MRR_1M,VAE_MRR_1M,RTals_MRR_1M,MPOP_mrr_1M,RRec_mrr_1M)), 
                         columns = cols_1)  #als_MRR_1M,
MRRDF_ML1M
# Out:
#         PSI   UpdtPSI       SVD       VAE      iALS      MPOP      RRec
# 0  0.021684  0.021786  0.019473  0.016403  0.021006  0.010174  0.000000
# 1  0.024197  0.023369  0.023609  0.022373  0.023399  0.007009  0.000000
# 2  0.031262  0.032823  0.035299  0.034472  0.035424  0.014248  0.000000
# 3  0.020147  0.019985  0.020142  0.027857  0.034254  0.006935  0.000000
# 4  0.014692  0.013880  0.017286  0.010846  0.013204  0.002798  0.000890
# 5  0.017142  0.016827  0.017076  0.015558  0.014210  0.004454  0.001061
# 6  0.019946  0.018896  0.024127  0.021189  0.025114  0.008228  0.000516
# 7  0.021279  0.021409  0.020408  0.020008  0.016873  0.005851  0.002660
# 8  0.023715  0.024646  0.025603  0.028510  0.022615  0.009682  0.000000
# 9  0.020008  0.018688  0.016128  0.018212  0.016527  0.001688  0.000345

# %%
makeplot(AllSteps_11,MRRDF_ML1M,y_label="MRR@10",x_label="Incremental Steps",title="MovieLen_1M MRR Plot")

# %%
 make_boxplot(MRRDF_ML1M,"MRR@10",'Models','MRR Range of Values (MovieLen_1M)')

# %% [markdown]
# ### cov_1m

# %%
MLDF_1Mcov_DF = pd.DataFrame(list(zip(RegPSI_Cov_1M,updt_COV_1M,svd_cov_1M,VAE_cov_1M,RTals_Cov_1M,Mpop_cov_1M,RRec_cov_1M)), 
                            columns =['PSI_COV','UpdtPSI_COV','SVD_COV','VAE_COV','iALS_COV','MPOP_COV','RRec_COV'])
MLDF_1Mcov_DF   #als_Cov_1M,'UpdtiALS_COV',
# Out:
#     PSI_COV  UpdtPSI_COV   SVD_COV   VAE_COV  iALS_COV  MPOP_COV  RRec_COV
# 0  0.155958     0.152845  0.155109  0.539202  0.230682   0.00283       1.0
# 1  0.157090     0.156524  0.155392  0.529578  0.230682   0.00283       1.0
# 2  0.155675     0.155392  0.154543  0.534673  0.234079   0.00283       1.0
# 3  0.155675     0.152279  0.155675  0.527314  0.232380   0.00283       1.0
# 4  0.156241     0.152279  0.158789  0.523634  0.233513   0.00283       1.0
# 5  0.158222     0.152845  0.157939  0.543731  0.234362   0.00283       1.0
# 6  0.158222     0.152562  0.157090  0.541749  0.233513   0.00283       1.0
# 7  0.158222     0.152845  0.157656  0.538919  0.234079   0.00283       1.0
# 8  0.158789     0.153694  0.158506  0.529012  0.236060   0.00283       1.0
# 9  0.156807     0.153411  0.155109  0.536654  0.237475   0.00283       1.0

# %%
makeplot(AllSteps_11,MLDF_1Mcov_DF,y_label="Coverage",x_label="Incremental Steps",title="MovieLen_1M Coverage Plot")

# %%
##Plot Overlapping


cov_listML1 = [RegPSI_Cov_1M, updt_COV_1M, svd_cov_1M, VAE_cov_1M, RTals_Cov_1M, Mpop_cov_1M, RRec_cov_1M]  #als_Cov_1M,
label_list   = [  'PSI',        'Updt_PSI',   'SVD',        'VAE',    'iALS',      'Most_POP', 'Rand_Rec']   #'Updt_iALS',
num_list = list(range(0,8))
plotoverlapping_2(cov_listML1,label_list,num_list,title="MovieLen_1M Coverage Plot",
                 x_label="Incremental Steps",y_label="Coverage",size=(12,8),n=11)

# %%
make_boxplot(MLDF_1Mcov_DF,"Coverage",'Models','Coverage Range of Values (MovieLen_1M)')

# %% [markdown]
# ###corr_1m

# %%
corrSteps_10 = list(range(1,10))
MLDF1M_CORR_DF = pd.DataFrame(list(zip(RegPSICorr_1M, updtCorr_1M, svd_corr_1M, VAE_corr_1M, RTiALSCorr_1M, Mpop_corr_1M, RRec_corr_1M)), 
                     columns =          ['PSI_Stby', 'UpdtPSI_Stby','SVD_Stby', 'VAE_Stby',   'iALS_Stby',   'MPOP_Stby',  'RRec_Stby'])
MLDF1M_CORR_DF   #iALSCorr_1M,'UpdtiALS_Stby',
# Out:
#    PSI_Stby  UpdtPSI_Stby  SVD_Stby  VAE_Stby  iALS_Stby  MPOP_Stby  RRec_Stby
# 0  0.959978      0.962097  0.932332  0.302358   0.639674   0.977495   0.000854
# 1  0.960605      0.960722  0.932419  0.302143   0.661117   0.933971   0.000993
# 2  0.956994      0.963055  0.926258  0.309156   0.648885   0.933971   0.000769
# 3  0.944815      0.976595  0.874062  0.304746   0.634643   0.933971   0.001023
# 4  0.943124      0.973171  0.811897  0.308245   0.626622   1.000000   0.000990
# 5  0.944156      0.975016  0.861049  0.303900   0.648794   0.990561   0.001021
# 6  0.941295      0.972369  0.857282  0.301369   0.643721   0.966431   0.000949
# 7  0.947399      0.975495  0.916621  0.304411   0.638638   0.966431   0.000709
# 8  0.951325      0.976939  0.916951  0.305228   0.646706   0.966431   0.000826

# %%
makeplot(corrSteps_10,MLDF1M_CORR_DF,y_label="Stability",x_label="Incremental Steps",title="MovieLen_1M Stability Plot")

# %%
##Plot Overlapping

corr_listML1 = [RegPSICorr_1M, updtCorr_1M, svd_corr_1M, VAE_corr_1M, RTiALSCorr_1M, Mpop_corr_1M, RRec_corr_1M]  #iALSCorr_1M,
label_list   = [    'PSI',       'Updt_PSI',   'SVD',        'VAE',      'iALS',     'Most_POP',   'Rand_Rec']    #'Updt_iALS', 
num_list = list(range(0,8))
plotoverlapping_2(corr_listML1,label_list,num_list,title="MovieLen_1M Stability Plot",
                  x_label="Incremental Steps",y_label="Stability",size=(12,8),n=10)

# %%
make_boxplot(MLDF1M_CORR_DF,"Stability",'Models','Stability Range of Values (MovieLen_1M)')

# %% [markdown]
# ### Latex Result

# %%
###MovieLen_1M 
plt.subplots(figsize=(18, 5))  

plt.subplot(1, 4, 1)  
plotoverlapping_3(corr_listML1,label_list,num_list,title="ML_1M Stability Plot(All steps)",
                  x_label="Incremental Steps",y_label="Stability",n=10)

plt.subplot(1, 4, 2) 
makeboxplot_2(ML1M_HitRDF," ",'Models','Hitrate (Range of values)')

plt.subplot(1, 4, 3) 
makeboxplot_2(MRRDF_ML1M," ",'Models','MRR (Range of values)')

plt.subplot(1, 4, 4)  
plotoverlapping_3(cov_listML1,label_list,num_list,title="ML_1M Coverage Plot(All steps)",
                 x_label="Incremental Steps",y_label="Values",n=11)

# spce between the plots
plt.tight_layout(0.5)
plt.show()

# %% [markdown]
# ## All Results: MovieLen_20M

# %% [markdown]
# ### hitr_20m

# %%
AllSteps_15 = list(range(1,16))
cols_1 = ['PSI','UpdtPSI','SVD','VAE','iALS','MPOP','RRec']
cols_2 = ['PSI_HR','UpdtPSI_HR','SVD_HR','VAE_HR','UpdtiALS_HR','iALS_HR','MPOP_HR','RRec_HR']
ML20M_HitRDF = pd.DataFrame(list(zip(RegPSI_HR_20m,updted_HR_20m,SVD_HitR_20m,VAEHitRat_20m,ials_HitR_RT_20m,MPOP_Hitr_20m,RRec_HitR_20m)), 
                          columns =cols_1)
ML20M_HitRDF  #'UpdtiALS',  ials_HitR_updt_20m,
# Out:
#          PSI   UpdtPSI       SVD       VAE      iALS      MPOP      RRec
# 0   0.052327  0.052327  0.060133  0.074877  0.057531  0.025152  0.000289
# 1   0.050740  0.051042  0.053760  0.061009  0.056780  0.015403  0.000604
# 2   0.050576  0.049936  0.057298  0.070102  0.053137  0.021127  0.000640
# 3   0.056180  0.054896  0.055538  0.069021  0.063563  0.020546  0.000000
# 4   0.057820  0.058452  0.062875  0.075829  0.058452  0.019905  0.000316
# 5   0.046482  0.045836  0.045513  0.057456  0.049064  0.017108  0.000646
# 6   0.047334  0.046071  0.046071  0.055222  0.050805  0.018618  0.001262
# 7   0.049537  0.049856  0.051774  0.072867  0.059764  0.027804  0.000320
# 8   0.055138  0.055138  0.054825  0.078947  0.071742  0.026942  0.000627
# 9   0.051041  0.050161  0.055441  0.075389  0.063655  0.022881  0.000880
# 10  0.053260  0.053872  0.055096  0.076217  0.060606  0.027242  0.000000
# 11  0.051999  0.053299  0.047449  0.072148  0.057524  0.023724  0.000325
# ...

# %%
makeplot(AllSteps_15,ML20M_HitRDF,y_label="HitRate@10",x_label="Incremental Steps",title="MovieLen_20M HitRate Plot")

# %%
make_boxplot(ML20M_HitRDF,"HitRate@10",'Models','HitRate Range of Values (MovieLen_20M)')

# %% [markdown]
# ### mrr_20m

# %%
cols_1 = ['PSI','UpdtPSI','SVD','VAE','iALS','MPOP','RRec']
cols_2 = ['PSI_MRR','UpdtPSI_MRR','SVD_MRR','VAE_MRR','iALS_MRR','MPOP_MRR','RRec_MRR']

MRRDF_ML20M = pd.DataFrame(list(zip(Regpsi_MRR_20m,updted_MRR_20m,SVD_MRR_20m,VAE_MRR_20m,RTals_MRR_20m,MPOP_mrr_20m,RRec_mrr_20m)), 
                           columns =cols_1 )
MRRDF_ML20M   #updtals_MRR_20m,'UpdtiALS_MRR',
# Out:
#          PSI   UpdtPSI       SVD       VAE      iALS      MPOP      RRec
# 0   0.021205  0.021351  0.022538  0.029338  0.021298  0.009457  0.000029
# 1   0.021965  0.021986  0.023183  0.023010  0.020325  0.004765  0.000136
# 2   0.019514  0.019723  0.021367  0.026060  0.018839  0.005644  0.000267
# 3   0.021846  0.021805  0.023214  0.028608  0.023648  0.007273  0.000000
# 4   0.024715  0.024415  0.026925  0.026217  0.022785  0.006787  0.000063
# 5   0.017992  0.017814  0.017539  0.021436  0.017929  0.004779  0.000145
# 6   0.018062  0.017870  0.018279  0.017782  0.017866  0.006831  0.000510
# 7   0.019478  0.019622  0.021182  0.028113  0.022683  0.008575  0.000053
# 8   0.024090  0.023996  0.024933  0.029159  0.027000  0.009201  0.000107
# 9   0.020874  0.021163  0.023589  0.028053  0.021308  0.008476  0.000293
# 10  0.024927  0.024777  0.024520  0.028610  0.021749  0.011268  0.000000
# 11  0.019256  0.019358  0.018858  0.028289  0.019226  0.007720  0.000046
# ...

# %%
makeplot(AllSteps_15,MRRDF_ML20M,y_label="MRR@10",x_label="Incremental Steps",title="MovieLen_20M MRR Plot")

# %%
make_boxplot(MRRDF_ML20M,"MRR@10",'Models','MRR Range of Values (MovieLen_20M)')

# %% [markdown]
# ### cov_20m

# %%
MLDF_20Mcov_DF = pd.DataFrame(list(zip(RegPSI_Cov_20m,updt_COV_20m,svd_cov_20m,VAE_cov_20m,RTals_Cov_20m,Mpop_cov_20m,RRec_cov_20m)), 
                              columns =['PSI_COV','UpdtPSI_COV','SVD_COV','VAE_COV','iALS_COV','MPOP_COV','RRec_COV'])
MLDF_20Mcov_DF   #updtals_Cov_20m,'UpdtiALS_COV',
# Out:
#      PSI_COV  UpdtPSI_COV   SVD_COV   VAE_COV  iALS_COV  MPOP_COV  RRec_COV
# 0   0.051834     0.051834  0.052654  0.264913  0.098456  0.000483       1.0
# 1   0.051931     0.051737  0.053041  0.258784  0.098842  0.000483       1.0
# 2   0.052220     0.052075  0.053378  0.263900  0.098745  0.000483       1.0
# 3   0.052172     0.052365  0.053620  0.259797  0.098986  0.000483       1.0
# 4   0.052317     0.052510  0.053330  0.262210  0.099469  0.000483       1.0
# 5   0.052365     0.052365  0.053523  0.261921  0.100531  0.000483       1.0
# 6   0.052654     0.052317  0.053764  0.269064  0.101014  0.000483       1.0
# 7   0.052944     0.052510  0.053861  0.276400  0.100917  0.000483       1.0
# 8   0.052992     0.052606  0.054247  0.279585  0.101110  0.000483       1.0
# 9   0.053234     0.052510  0.054247  0.276255  0.101400  0.000483       1.0
# 10  0.053282     0.052751  0.054295  0.291409  0.101641  0.000483       1.0
# ...

# %%
cov_listML20  = [RegPSI_Cov_20m,updt_COV_20m,svd_cov_20m,VAE_cov_20m,RTals_Cov_20m,Mpop_cov_20m,RRec_cov_20m] #updtals_Cov_20m,
label_list= [ 'PSI',      'Updt_PSI',    'SVD',       'VAE',         'iALS',       'Most_POP',   'Rand_Rec']  #'Updt_iALS',  
num_list = list(range(0,8))

plotoverlapping_2(cov_listML20,label_list,num_list,title="MovieLen_20M Coverage Plot",
                 x_label="Incremental Steps",y_label="Coverage",size=(12,8),n=16)

# %%
makeplot(AllSteps_15,MLDF_20Mcov_DF,y_label="Coverage",x_label="Incremental Steps",title="MovieLen_20M Coverage Plot")

# %%
make_boxplot(MLDF_20Mcov_DF,"Coverage",'Models','Coverage Range of Values (MovieLen_20M)')

# %% [markdown]
# ###Corr_20m

# %%
MLDF20M_CORR_DF = pd.DataFrame(list(zip(RegPSICorr_20m,updtCorr_20m,svd_corr_20m,VAE_corr_20m,RTiALSCorr_20m,Mpop_corr_20m,RRec_corr_20m)), 
                              columns =['PSI_Stby', 'UpdtedPSI_Stby',  'SVD_Stby', 'VAE_Stby', 'iALS_Stby','MPOP_Stby','RRec_Stby'])
MLDF20M_CORR_DF  #updtiALSCorr_20m, 'updt_iALS_Stby',
# Out:
#     PSI_Stby  UpdtedPSI_Stby  SVD_Stby  ...  iALS_Stby  MPOP_Stby  RRec_Stby
# 0   0.983549        0.985692  0.901389  ...   0.581935   1.000000   0.000149
# 1   0.984046        0.985231  0.950430  ...   0.566773   1.000000   0.000147
# 2   0.983363        0.985067  0.949446  ...   0.568414   1.000000   0.000163
# 3   0.983726        0.985232  0.948738  ...   0.580375   1.000000   0.000154
# 4   0.984254        0.985598  0.951047  ...   0.582754   1.000000   0.000143
# 5   0.984872        0.986026  0.953296  ...   0.581416   1.000000   0.000150
# 6   0.983826        0.984842  0.952249  ...   0.591566   0.987880   0.000158
# 7   0.983472        0.983876  0.945487  ...   0.569891   1.000000   0.000157
# 8   0.983918        0.984840  0.884310  ...   0.573910   0.990561   0.000145
# 9   0.984037        0.984862  0.926300  ...   0.575130   1.000000   0.000165
# 10  0.984472        0.985298  0.948119  ...   0.586815   0.933971   0.000153
# ...

# %%
AllSteps_14 = list(range(1,15))
print(len(AllSteps_14))     
makeplot(AllSteps_14,MLDF20M_CORR_DF,y_label="Stability",x_label="Incremental Steps",title="MovieLen_20M Stability Plot")
# Out:
# 14

# %%
##Plot for Overlapping Results
corr_list20M = [RegPSICorr_20m, updtCorr_20m, svd_corr_20m, VAE_corr_20m, RTiALSCorr_20m, Mpop_corr_20m, RRec_corr_20m]  #updtiALSCorr_20m,
label_list   = [    'PSI',     'Updt_PSI',      'SVD',        'VAE',        'iALS',        'Most_POP',    'Rand_Rec']  #'Updt_iALS',   
num_list = list(range(0,8))
plotoverlapping_2(corr_list20M,label_list,num_list,title="MovieLen_20M Stability Plot",
                 x_label="Incremental Steps",y_label="Stability",size=(12,8),n=15)

# %%
make_boxplot(MLDF20M_CORR_DF,"Stability",'Models','Stability Range of Values (MovieLen_20M)')

# %% [markdown]
# ### Latex Result

# %%
##MovieLen_20m
plt.subplots(figsize=(18,5))  

plt.subplot(1, 4, 1)  
plotoverlapping_3(corr_list20M,label_list,num_list,title= "ML_20M Stability Plot(All steps)",
                 x_label="Incremental Steps",y_label="Values",n=15)  #

plt.subplot(1, 4, 2) 
makeboxplot_2(ML20M_HitRDF," ",' ','Hitrate (Range of values)')  #
plt.xlabel('Models',fontsize=14)

plt.subplot(1, 4, 3) 
makeboxplot_2(MRRDF_ML20M," ",' ','MRR (Range of values)')  #MRR (Range of values)
plt.xlabel('Models',fontsize=14)

plt.subplot(1, 4, 4) 
plotoverlapping_3(cov_listML20,label_list,num_list,title="ML_20M Coverage Plot(All steps)",  #
                 x_label="Incremental Steps",y_label=" ",n=16) 
#plt.legend(loc=3,bbox_to_anchor=(1,0))
# spce between the plots
plt.tight_layout(0.5)
plt.show()
