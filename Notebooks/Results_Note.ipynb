# %% [markdown]
# ## All Results :Amazon_Bty

# %% [markdown]
# ### hitr_amb

# %%
AMZB_HitRDF = pd.DataFrame(list(zip(RegPSI_HR_amb,updted_HR_amb,SVD_HitR_amb,VAEHitRat_amb,ials_HitR_amb,RTials_HitR_amb,MPOP_Hitr_amb,RRec_HitR_amb)), 
                          columns =['PSI_HR','UpdtPSI_HR','SVD_HR','VAE_HR','UpdtiALS_HR','iALS_HR','MPOP_HR','RRec_HR'])
AMZB_HitRDF
# Out:
#      PSI_HR  UpdtPSI_HR    SVD_HR  ...   iALS_HR   MPOP_HR   RRec_HR
# 0  0.267932    0.267932  0.297468  ...  0.312236  0.139241  0.000000
# 1  0.341801    0.344111  0.321016  ...  0.392610  0.214781  0.002309
# 2  0.337634    0.335484  0.318280  ...  0.400000  0.189247  0.002151
# 3  0.301255    0.305439  0.317992  ...  0.380753  0.173640  0.002092
# 4  0.282427    0.284519  0.309623  ...  0.361925  0.138075  0.000000
# 5  0.273622    0.273622  0.299213  ...  0.395669  0.141732  0.000000
# 6  0.274510    0.284314  0.333333  ...  0.689542  0.562092  0.000000
# 7  0.248748    0.252087  0.273790  ...  0.420701  0.191987  0.000000
# 8  0.307836    0.302239  0.335821  ...  0.436567  0.166045  0.001866
# 9  0.143529    0.136471  0.190588  ...  0.244706  0.164706  0.000000
#
# [10 rows x 8 columns]

# %%
AllSteps_10 = list(range(1,11))
makeplot(AllSteps_10,AMZB_HitRDF,y_label="HitRate@10",x_label="Incremental Steps",title="Amazon Beauty HitRate Plot")

# %%
 make_boxplot(AMZB_HitRDF,"HitRate@10",'Models','Hitrate Range of Values for Each Model(AMZ_Bty)')

# %% [markdown]
# ### mrr_amb

# %%
AMZBMRR_DF = pd.DataFrame(list(zip(Regpsi_MRR_amb,updted_MRR_amb,SVD_MRR_amb,VAE_MRR_amb,als_MRR_amb,RTals_MRR_amb,MPOP_mrr_amb,RRec_mrr_amb)), 
                        columns =['PSI_MRR','UpdtPSI_MRR','SVD_MRR','VAE_MRR','UpdtiALS_MRR','iALS_MRR','MPOP_MRR','RRec_MRR'])
AMZBMRR_DF
# Out:
#     PSI_MRR  UpdtPSI_MRR   SVD_MRR  ...  iALS_MRR  MPOP_MRR  RRec_MRR
# 0  0.239419     0.241227  0.257904  ...  0.286520  0.044069  0.000000
# 1  0.296410     0.298919  0.265928  ...  0.348428  0.074903  0.000770
# 2  0.312709     0.311335  0.282022  ...  0.344253  0.050269  0.000430
# 3  0.269700     0.271502  0.277618  ...  0.335785  0.046131  0.000299
# 4  0.260157     0.260327  0.276946  ...  0.313232  0.032681  0.000000
# 5  0.243877     0.245122  0.262233  ...  0.308541  0.051005  0.000000
# 6  0.211119     0.205629  0.252534  ...  0.549020  0.348972  0.000000
# 7  0.219799     0.215582  0.238937  ...  0.345979  0.048820  0.000000
# 8  0.259858     0.259141  0.271409  ...  0.365187  0.057332  0.000187
# 9  0.116059     0.113294  0.152591  ...  0.169874  0.047238  0.000000
#
# [10 rows x 8 columns]

# %%
makeplot(AllSteps_10,AMZBMRR_DF,y_label="MRR@10",x_label="Incremental Steps",title="Amazon Beauty MRR Plot")

# %%
 make_boxplot(AMZBMRR_DF,"MRR@10",'Models','MRR Range of Values for Each Model(AMZ_Bty)')

# %% [markdown]
# ###cov_amb

# %%
AMZB_cov_DF = pd.DataFrame(list(zip(RegPSI_Cov_amb,updt_COV_amb,svd_cov_amb,VAE_cov_amb,als_Cov_amb,RTals_Cov_amb,Mpop_cov_amb,RRec_cov_amb)), 
                            columns =['PSI_COV','UpdtPSI_COV','SVD_COV','VAE_COV','UpdtiALS_COV','iALS_COV','MPOP_COV','RRec_COV'])
AMZB_cov_DF
# Out:
#     PSI_COV  UpdtPSI_COV   SVD_COV  ...  iALS_COV  MPOP_COV  RRec_COV
# 0  0.079788     0.079911  0.079788  ...  0.013812  0.001233       1.0
# 1  0.080035     0.081884  0.081021  ...  0.013812  0.001233       1.0
# 2  0.080281     0.083364  0.079788  ...  0.014182  0.001233       1.0
# 3  0.080035     0.084351  0.079295  ...  0.014182  0.001233       1.0
# 4  0.079295     0.083981  0.079665  ...  0.014182  0.001233       1.0
# 5  0.078925     0.083118  0.079048  ...  0.014182  0.001233       1.0
# 6  0.078308     0.083487  0.080035  ...  0.014428  0.001233       1.0
# 7  0.078678     0.082008  0.080035  ...  0.014428  0.001233       1.0
# 8  0.077568     0.082131  0.079911  ...  0.014428  0.001233       1.0
# 9  0.076458     0.082871  0.079418  ...  0.014428  0.001233       1.0
#
# [10 rows x 8 columns]

# %%
AllSteps_10 = list(range(1,11))
makeplot(AllSteps_10,AMZB_cov_DF,y_label="Coverage",x_label="Incremental Steps",title="Amazon Beauty Coverage Plot")

# %%
##Plot Overlapping
cov_listAMB = [RegPSI_Cov_amb, updt_COV_amb, svd_cov_amb, VAE_cov_amb, als_Cov_amb, RTals_Cov_amb, Mpop_cov_amb, RRec_cov_amb] 
label_list   = [    'PSI',       'Updt_PSI',   'SVD',        'VAE',       'Updt_iALS', 'iALS',       'Most_POP',   'Rand_Rec']
num_list = list(range(0,8))
plot_overlapping(cov_listAMB,label_list,num_list,title="Amazon Beauty Coverage Plot",
                 x_label="Incremental Steps",y_label="Coverage",size=(12,8),n=11)

# %%
 make_boxplot(AMZB_cov_DF,"Coverage",'Models','Coverage Range of Values for Each Model(AMZ_Bty)')

# %% [markdown]
# ### Stability

# %%
corrSteps = list(range(1,10))
print(len(corrSteps))   
corrSteps
# Out:
# 9
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
AMZB_Stability = pd.DataFrame(list(zip(RegPSICorr_amb,updtCorr_amb,svd_corr_amb,VAE_corr_amb,iALSCorr_amb,RTiALSCorr_amb,Mpop_corr_amb,RRec_corr_amb)), 
                   columns =['PSI_STBty','UpdtPSI_STBty','SVD_STBty','VAE_STBty','UpdtiALS_STBty','iALS_STBty','MPOP_STBty','RRec_STBty'])
AMZB_Stability
# Out:
#    PSI_STBty  UpdtPSI_STBty  SVD_STBty  ...  iALS_STBty  MPOP_STBty  RRec_STBty
# 0   0.965020       0.950746   0.727653  ...    0.996296    0.352823    0.000342
# 1   0.965463       0.954120   0.780091  ...    0.995866    0.333032    0.000414
# 2   0.969593       0.946259   0.795077  ...    0.995830    0.369007    0.000372
# 3   0.968605       0.954978   0.777971  ...    0.995895    0.373465    0.000365
# 4   0.952741       0.955831   0.831617  ...    0.996192    0.331830    0.000346
# 5   0.960141       0.950735   0.691071  ...    0.994420    0.145851    0.000392
# 6   0.962292       0.949373   0.740505  ...    0.991682    0.212086    0.000406
# 7   0.943946       0.938544   0.792581  ...    0.994866    0.153371    0.000331
# 8   0.970057       0.962109   0.795507  ...    0.995339    0.354560    0.000339
#
# [9 rows x 8 columns]

# %%
corrSteps = list(range(1,10))
makeplot(corrSteps,AMZB_Stability,y_label="Stability",x_label="Incremental Steps",title="Amazon Beauty Stability Plot")

# %%
##Plot Overlapping

corr_listAMB = [RegPSICorr_amb,updtCorr_amb,svd_corr_amb,VAE_corr_amb,iALSCorr_amb,RTiALSCorr_amb,Mpop_corr_amb,RRec_corr_amb] 
label_list   = [    'PSI',       'Updt_PSI',   'SVD',        'VAE',       'Updt_iALS', 'iALS',       'Most_POP',   'Rand_Rec']
num_list = list(range(0,8))
plot_overlapping(corr_listAMB,label_list,num_list,title="Amazon Beauty Stability Plot",
                 x_label="Incremental Steps",y_label="Stability",size=(12,8),n=10)

# %%
make_boxplot(AMZB_Stability,"Stability",'Models','Stability Range of Values for Each Model(AMZ_Bty)')

# %% [markdown]
# ## All Results : Amazon_Gmz

# %% [markdown]
# ### hitr_amg

# %%
AMZGames_HitR_DF = pd.DataFrame(list(zip(RegPSI_HR_amg,updted_HR_amg,SVD_HR_amg,VAEHitRat_amg,updtials_HR_amg,RTials_HR_amg,MPOP_HR_amg,RRec_HR_amg)), 
                                     columns =['PSI_HR','UpdtPSI_HR','SVD_HR','VAE_HR','UpdtiALS_HR','iALS_HR','MPOP_HR','RRec_HR'])
AMZGames_HitR_DF
# Out:
#       PSI_HR  UpdtPSI_HR    SVD_HR  ...   iALS_HR   MPOP_HR   RRec_HR
# 0   0.030228    0.028741  0.047572  ...  0.135778  0.056492  0.000991
# 1   0.028636    0.028636  0.045000  ...  0.137727  0.042727  0.001364
# 2   0.037293    0.036832  0.042357  ...  0.172192  0.109116  0.000460
# 3   0.026936    0.027898  0.048100  ...  0.153439  0.063011  0.000962
# 4   0.033509    0.031115  0.054093  ...  0.136908  0.037338  0.000000
# 5   0.025472    0.025000  0.048585  ...  0.124528  0.054717  0.001887
# 6   0.022102    0.020298  0.037889  ...  0.122237  0.066757  0.001353
# 7   0.021749    0.019937  0.033530  ...  0.140462  0.080199  0.001812
# 8   0.026723    0.024379  0.049226  ...  0.145804  0.063760  0.000938
# 9   0.026716    0.023491  0.049286  ...  0.170889  0.073699  0.000000
# 10  0.020345    0.019018  0.040690  ...  0.167183  0.092437  0.000442
# 11  0.024488    0.021817  0.046750  ...  0.146037  0.060107  0.000000
# 12  0.030055    0.027322  0.052823  ...  0.134335  0.041439  0.000000
# 13  0.024240    0.022036  0.055972  ...  0.137506  0.056853  0.000000
# 14  0.009451    0.009001  0.028803  ...  0.039154  0.074257  0.000000
#
# [15 rows x 8 columns]

# %%
makeplot(AllSteps_15,AMZGames_HitR_DF,y_label="HitRate@10",x_label="Incremental Steps",title="AmazonGames HitRate Allsteps")

# %%
make_boxplot(AMZGames_HitR_DF,"HitRate@10",'Models','HitRate Range of Values for Each Model(AMZ_Games)')

# %% [markdown]
# ###mrr_amg

# %%
AMZGames_mrr = pd.DataFrame(list(zip(psi_MRR_amg,updted_MRR_amg,SVD_MRR_amg,VAE_MRR_amg,als_MRR_amg,RTals_MRR_amg,MPOP_mrr_amg,RRec_mrr_amg)), 
                            columns =['PSI_MRR','UpdtPSI_MRR','SVD_MRR','VAE_MRR','UpdtiALS_MRR','iALS_MRR','MPOP_MRR','RRec_MRR'])
AMZGames_mrr
# Out:
#      PSI_MRR  UpdtPSI_MRR   SVD_MRR  ...  iALS_MRR  MPOP_MRR  RRec_MRR
# 0   0.010435     0.010185  0.019358  ...  0.047720  0.014842  0.000578
# 1   0.013650     0.013654  0.023652  ...  0.053833  0.017453  0.000338
# 2   0.013784     0.013380  0.020143  ...  0.073051  0.073580  0.000153
# 3   0.010830     0.011199  0.022079  ...  0.061129  0.041228  0.000168
# 4   0.012396     0.011477  0.025752  ...  0.058823  0.010669  0.000000
# 5   0.009929     0.009797  0.028113  ...  0.053896  0.013654  0.000218
# 6   0.008309     0.007529  0.021062  ...  0.051082  0.016224  0.000182
# 7   0.008626     0.009307  0.015026  ...  0.058526  0.031779  0.000374
# 8   0.010060     0.009586  0.019633  ...  0.062536  0.026740  0.000586
# 9   0.011204     0.010436  0.021855  ...  0.076733  0.040723  0.000000
# 10  0.007652     0.007218  0.019073  ...  0.073479  0.055073  0.000063
# 11  0.006467     0.005953  0.020220  ...  0.061514  0.016494  0.000000
# 12  0.011027     0.010094  0.022113  ...  0.057076  0.017951  0.000000
# 13  0.009598     0.009585  0.025357  ...  0.064686  0.030230  0.000000
# 14  0.003073     0.002721  0.012638  ...  0.014476  0.030534  0.000000
#
# [15 rows x 8 columns]

# %%
makeplot(AllSteps_15,AMZGames_mrr,y_label="MRR@10",x_label="Incremental Steps",title="AmazonGames MRR Allsteps")

# %%
make_boxplot(AMZGames_mrr,"MRR@10",'Models','MRR Range of Values for Each Model(AMZ_Games)')

# %% [markdown]
# ###cov_amg

# %%
AMZGames_covDF = pd.DataFrame(list(zip(PSI_Cov_AMG,updt_COV_AMG,svd_cov_AMG,VAE_cov_AMG,als_Cov_AMG,RTals_Cov_AMG,Mpop_cov_AMG,RRec_cov_AMG)), 
                             columns =['PSI_COV','UpdtPSI_COV','SVD_COV','VAE_COV','UpdtiALS_COV','iALS_COV','MPOP_COV','RRec_COV'])
AMZGames_covDF
# Out:
#      PSI_COV  UpdtPSI_COV   SVD_COV  ...  iALS_COV  MPOP_COV  RRec_COV
# 0   0.045502     0.045560  0.045560  ...  0.067444  0.000577       1.0
# 1   0.045386     0.045444  0.045791  ...  0.067618  0.000577       1.0
# 2   0.045213     0.045444  0.045560  ...  0.067618  0.000577       1.0
# 3   0.045098     0.045560  0.045213  ...  0.067560  0.000577       1.0
# 4   0.045040     0.045444  0.045213  ...  0.067675  0.000577       1.0
# 5   0.045329     0.044809  0.045386  ...  0.067675  0.000577       1.0
# 6   0.045040     0.045213  0.045906  ...  0.067675  0.000577       1.0
# 7   0.045386     0.044693  0.045906  ...  0.067733  0.000577       1.0
# 8   0.045040     0.044751  0.046541  ...  0.067791  0.000577       1.0
# 9   0.045271     0.045271  0.046368  ...  0.067733  0.000577       1.0
# 10  0.045329     0.044924  0.046714  ...  0.067675  0.000577       1.0
# 11  0.045386     0.045675  0.047061  ...  0.067675  0.000577       1.0
# 12  0.045502     0.045617  0.046483  ...  0.067618  0.000577       1.0
# 13  0.045906     0.045560  0.046426  ...  0.067618  0.000577       1.0
# 14  0.045733     0.045502  0.045791  ...  0.067618  0.000577       1.0
#
# [15 rows x 8 columns]

# %%
makeplot(AllSteps_15,AMZGames_covDF,y_label="Coverage",x_label="Incremental Steps",title="AmazonGames Coverage Allsteps")

# %%
##Plot Overlapping

cov_listAMG =  [PSI_Cov_AMG, updt_COV_AMG, svd_cov_AMG, VAE_cov_AMG, als_Cov_AMG, RTals_Cov_AMG, Mpop_cov_AMG, RRec_cov_AMG] 
label_list   = [  'PSI',        'Updt_PSI',   'SVD',        'VAE',    'Updt_iALS', 'iALS',        'Most_POP',   'Rand_Rec']
num_list = list(range(0,8))
plot_overlapping(cov_listAMG,label_list,num_list,title="AmazonGames Coverage Allsteps",
                 x_label="Incremental Steps",y_label="Coverage",size=(12,8),n=16)

# %%
make_boxplot(AMZGames_covDF,"Coverage",'Models','Coverage Range of Values for Each Model(AMZ_Games)')

# %% [markdown]
# ###corr_amg

# %%
AMZGamesCORR_DF = pd.DataFrame(list(zip(RegPSICorr_AMG,updtCorr_AMG,svd_corr_AMG,VAE_corr_AMG,iALSCorr_AMG,RTiALSCorr_AMG,Mpop_corr_AMG,RRec_corr_AMG)), 
                              columns =['PSI_Stby','UpdtPSI_Stby','SVD_Stby','VAE_Stby','UpdtiALS_Stby','iALS_Stby','MPOP_Stby','RRec_Stby'])
AMZGamesCORR_DF
# Out:
#     PSI_Stby  UpdtPSI_Stby  SVD_Stby  ...  iALS_Stby  MPOP_Stby  RRec_Stby
# 0   0.955858      0.968073  0.803770  ...   0.996910   0.307876   0.000189
# 1   0.954190      0.965862  0.801934  ...   0.996643   0.091622   0.000155
# 2   0.954668      0.965371  0.806677  ...   0.996334   0.282871   0.000170
# 3   0.955089      0.966996  0.781002  ...   0.996621   0.233353   0.000187
# 4   0.955406      0.968735  0.843642  ...   0.996597   0.271928   0.000165
# 5   0.956226      0.970095  0.847913  ...   0.997016   0.187802   0.000187
# 6   0.956999      0.967685  0.867813  ...   0.996890   0.295480   0.000188
# 7   0.958716      0.968398  0.858857  ...   0.996416   0.327279   0.000170
# 8   0.953972      0.967509  0.834692  ...   0.996501   0.274674   0.000189
# 9   0.956804      0.967135  0.836206  ...   0.995962   0.160717   0.000157
# 10  0.957235      0.971304  0.815944  ...   0.995982   0.270068   0.000184
# 11  0.958582      0.969014  0.817725  ...   0.996709   0.134491   0.000185
# 12  0.958229      0.967648  0.835268  ...   0.996583   0.183516   0.000187
# 13  0.961903      0.970012  0.836689  ...   0.996752   0.123269   0.000172
#
# [14 rows x 8 columns]

# %%
AllSteps_14 = list(range(1,15))
makeplot(AllSteps_14,AMZGamesCORR_DF,y_label="Satbility",x_label="Incremental Steps",title="AmazonGames Satbility Allsteps")

# %%
#Plot Overlapping
                              
corr_listAMG = [RegPSICorr_AMG, updtCorr_AMG, svd_corr_AMG, VAE_corr_AMG, iALSCorr_AMG, RTiALSCorr_AMG, Mpop_corr_AMG, RRec_corr_AMG]  
label_list   = [    'PSI',        'Updt_PSI',   'SVD',        'VAE',       'Updt_iALS',  'iALS',        'Most_POP',    'Rand_Rec']
num_list = list(range(0,8))
plot_overlapping(corr_listAMG,label_list,num_list,title= "AmazonGames Satbility Allsteps",
                 x_label="Incremental Steps",y_label="Stability",size=(12,8),n=15)

# %% [markdown]
# ## All Results: MovieLen_1M

# %% [markdown]
# ### hitr_1m

# %%
ML1M_HitRDF = pd.DataFrame(list(zip(RegPSI_HR_1M,updted_HR_1M,SVD_HitR_1M,VAEHitRat_ml1,ials_HitR_1M,RT_ialsHitR_1M,MPOP_Hitr_1M,RRec_HitR_1M)), 
                          columns =['PSI_HR','UpdtPSI_HR','SVD_HR','VAE_HR','UpdtiALS_HR','iALS_HR','MPOP_HR','RRec_HR'])
ML1M_HitRDF
# Out:
#      PSI_HR  UpdtPSI_HR    SVD_HR  ...   iALS_HR   MPOP_HR   RRec_HR
# 0  0.072961    0.072961  0.072961  ...  0.055794  0.025751  0.000000
# 1  0.086275    0.078431  0.082353  ...  0.047059  0.035294  0.000000
# 2  0.083916    0.083916  0.087413  ...  0.101399  0.041958  0.000000
# 3  0.067961    0.064725  0.064725  ...  0.064725  0.012945  0.000000
# 4  0.047009    0.042735  0.049145  ...  0.038462  0.051282  0.004274
# 5  0.047529    0.043726  0.051331  ...  0.041825  0.127376  0.005703
# 6  0.054159    0.052224  0.065764  ...  0.034816  0.114120  0.003868
# 7  0.046809    0.046809  0.046809  ...  0.031915  0.061702  0.004255
# 8  0.061810    0.061810  0.064018  ...  0.035320  0.055188  0.000000
# 9  0.055249    0.055249  0.052486  ...  0.052486  0.041436  0.002762
#
# [10 rows x 8 columns]

# %%
makeplot(AllSteps_11,ML1M_HitRDF,y_label="HitRate@10",x_label="Incremental Steps",title="MovieLen_1M HitRate Allsteps")

# %%
 make_boxplot(ML1M_HitRDF,"HitRate@10",'Models','HitRate Range of Values for Each Model(ML_1M)')

# %% [markdown]
# ###mrr_1m

# %%
MRRDF_ML1M = pd.DataFrame(list(zip(Regpsi_MRR_1M,updted_MRR_1M,SVD_MRR_1M,VAE_MRR_1M,als_MRR_1M,RTals_MRR_1M,MPOP_mrr_1M,RRec_mrr_1M)), 
                         columns =['PSI_MRR','UpdtPSI_MRR','SVD_MRR','VAE_MRR','UpdtiALS_MRR','iALS_MRR','MPOP_MRR','RRec_MRR'])
MRRDF_ML1M
# Out:
#     PSI_MRR  UpdtPSI_MRR   SVD_MRR  ...  iALS_MRR  MPOP_MRR  RRec_MRR
# 0  0.021684     0.021786  0.019473  ...  0.012285  0.006521  0.000000
# 1  0.024197     0.023369  0.023609  ...  0.016704  0.012325  0.000000
# 2  0.031262     0.032823  0.035299  ...  0.038849  0.017055  0.000000
# 3  0.020147     0.019985  0.020142  ...  0.017435  0.002543  0.000000
# 4  0.014692     0.013880  0.017286  ...  0.007294  0.026788  0.000890
# 5  0.017142     0.016827  0.017076  ...  0.011021  0.050039  0.001061
# 6  0.019946     0.018896  0.024127  ...  0.010794  0.045607  0.000516
# 7  0.021279     0.021409  0.020408  ...  0.010074  0.022773  0.002660
# 8  0.023715     0.024646  0.025603  ...  0.009390  0.020588  0.000000
# 9  0.020008     0.018688  0.016128  ...  0.018622  0.007988  0.000345
#
# [10 rows x 8 columns]

# %%
makeplot(AllSteps_11,MRRDF_ML1M,y_label="MRR@10",x_label="Incremental Steps",title="MovieLen_1M MRR Allsteps")

# %%
 make_boxplot(MRRDF_ML1M,"MRR@10",'Models','MRR Range of Values for Each Model(ML_1M)')

# %% [markdown]
# ### cov_1m

# %%
MLDF_1Mcov_DF = pd.DataFrame(list(zip(RegPSI_Cov_1M,updt_COV_1M,svd_cov_1M,VAE_cov_1M,als_Cov_1M,RTals_Cov_1M,Mpop_cov_1M,RRec_cov_1M)), 
                            columns =['PSI_COV','UpdtPSI_COV','SVD_COV','VAE_COV','UpdtiALS_COV','iALS_COV','MPOP_COV','RRec_COV'])
MLDF_1Mcov_DF
# Out:
#     PSI_COV  UpdtPSI_COV   SVD_COV  ...  iALS_COV  MPOP_COV  RRec_COV
# 0  0.155958     0.152845  0.155109  ...  0.459949   0.00283       1.0
# 1  0.157090     0.156524  0.155392  ...  0.459949   0.00283       1.0
# 2  0.155675     0.155392  0.154543  ...  0.460515   0.00283       1.0
# 3  0.155675     0.152279  0.155675  ...  0.461081   0.00283       1.0
# 4  0.156241     0.152279  0.158789  ...  0.461081   0.00283       1.0
# 5  0.158222     0.152845  0.157939  ...  0.461364   0.00283       1.0
# 6  0.158222     0.152562  0.157090  ...  0.461930   0.00283       1.0
# 7  0.158222     0.152845  0.157656  ...  0.461647   0.00283       1.0
# 8  0.158789     0.153694  0.158506  ...  0.461364   0.00283       1.0
# 9  0.156807     0.153411  0.155109  ...  0.461081   0.00283       1.0
#
# [10 rows x 8 columns]

# %%
makeplot(AllSteps_11,MLDF_1Mcov_DF,y_label="Coverage",x_label="Incremental Steps",title="MovieLen_1M Coverage Allsteps")

# %%
##Plot Overlapping


cov_listML1 = [RegPSI_Cov_1M, updt_COV_1M, svd_cov_1M, VAE_cov_1M, als_Cov_1M, RTals_Cov_1M, Mpop_cov_1M, RRec_cov_1M]
label_list   = [  'PSI',        'Updt_PSI',   'SVD',        'VAE',    'Updt_iALS', 'iALS',      'Most_POP', 'Rand_Rec']
num_list = list(range(0,8))
plot_overlapping(cov_listML1,label_list,num_list,title="MovieLen_1M Coverage Allsteps",
                 x_label="Incremental Steps",y_label="Coverage",size=(12,8),n=11)

# %%
 make_boxplot(MLDF_1Mcov_DF,"Coverage",'Models','Coverage Range of Values for Each Model(ML_1M)')

# %% [markdown]
# ###corr_1m

# %%
corrSteps_10 = list(range(1,10))
print(len(corrSteps_10))   
corrSteps_10
# Out:
# 9
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
MLDF1M_CORR_DF = pd.DataFrame(list(zip(RegPSICorr_1M,updtCorr_1M,svd_corr_1M,VAE_corr_1M,iALSCorr_1M,RTiALSCorr_1M,Mpop_corr_1M,RRec_corr_1M)), 
                             columns =['PSI_Stby','UpdtPSI_Stby','SVD_Stby','VAE_Stby','UpdtiALS_Stby','iALS_Stby','MPOP_Stby','RRec_Stby'])
MLDF1M_CORR_DF
# Out:
#    PSI_Stby  UpdtPSI_Stby  SVD_Stby  ...  iALS_Stby  MPOP_Stby  RRec_Stby
# 0  0.959978      0.962097  0.932332  ...   0.997106   0.316508   0.000854
# 1  0.960605      0.960722  0.932419  ...   0.997055   0.307066   0.000993
# 2  0.956994      0.963055  0.926258  ...   0.994971   0.208217   0.000769
# 3  0.944815      0.976595  0.874062  ...   0.991742   0.077361   0.001023
# 4  0.943124      0.973171  0.811897  ...   0.990937   0.135713   0.000990
# 5  0.944156      0.975016  0.861049  ...   0.991772   0.368119   0.001021
# 6  0.941295      0.972369  0.857282  ...   0.991517   0.446971   0.000949
# 7  0.947399      0.975495  0.916621  ...   0.993139   0.329670   0.000709
# 8  0.951325      0.976939  0.916951  ...   0.994027   0.096731   0.000826
#
# [9 rows x 8 columns]

# %%
makeplot(corrSteps_10,MLDF1M_CORR_DF,y_label="Stability",x_label="Incremental Steps",title="MovieLen_1M Stability Allsteps")

# %%
##Plot Overlapping

corr_listML1 = [RegPSICorr_1M, updtCorr_1M, svd_corr_1M, VAE_corr_1M, iALSCorr_1M, RTiALSCorr_1M,Mpop_corr_1M, RRec_corr_1M]  
label_list   = [    'PSI',       'Updt_PSI',   'SVD',        'VAE',       'Updt_iALS', 'iALS',    'Most_POP',   'Rand_Rec']
num_list = list(range(0,8))
plot_overlapping(corr_listML1,label_list,num_list,title="MovieLen_1M Stability Allsteps",
                 x_label="Incremental Steps",y_label="Stability",size=(12,8),n=10)

# %%
 make_boxplot(MLDF1M_CORR_DF,"Stability",'Models','Coverage Range of Values for Each Model(ML_1M)')

# %% [markdown]
# ## All Results: MovieLen_20M

# %% [markdown]
# ### hitr_20m

# %%
ML20M_HitRDF = pd.DataFrame(list(zip(RegPSI_HR_20m,updted_HR_20m,SVD_HitR_20m,VAEHitRat_20m,ials_HitR_updt_20m,ials_HitR_RT_20m,MPOP_Hitr_20m,RRec_HitR_20m)), 
                          columns =['PSI_HR','UpdtPSI_HR','SVD_HR','VAE_HR','UpdtiALS_HR','iALS_HR','MPOP_HR','RRec_HR'])
ML20M_HitRDF
# Out:
#       PSI_HR  UpdtPSI_HR    SVD_HR  ...   iALS_HR   MPOP_HR   RRec_HR
# 0   0.052905    0.053484  0.059266  ...  0.040763  0.028332  0.000289
# 1   0.048324    0.048324  0.049834  ...  0.040169  0.020538  0.000604
# 2   0.052177    0.052177  0.054097  ...  0.040973  0.022407  0.000640
# 3   0.052648    0.051364  0.058427  ...  0.043981  0.033708  0.000000
# 4   0.054660    0.054660  0.057504  ...  0.043286  0.049605  0.000316
# 5   0.049064    0.049709  0.049709  ...  0.035830  0.046482  0.000646
# 6   0.044178    0.042916  0.046387  ...  0.037236  0.049858  0.001262
# 7   0.053372    0.053691  0.057526  ...  0.046021  0.033877  0.000320
# 8   0.058584    0.058271  0.061090  ...  0.044486  0.033835  0.000627
# 9   0.053388    0.053681  0.054855  ...  0.046055  0.048108  0.000880
# 10  0.055403    0.055709  0.060606  ...  0.038874  0.034894  0.000000
# 11  0.050049    0.050374  0.052974  ...  0.041274  0.038999  0.000325
# 12  0.059885    0.059524  0.066739  ...  0.045455  0.027056  0.000361
# 13  0.054085    0.053707  0.059380  ...  0.039713  0.044251  0.000756
# 14  0.059341    0.058608  0.062637  ...  0.034432  0.041758  0.001099
#
# [15 rows x 8 columns]

# %%
makeplot(AllSteps_15,ML20M_HitRDF,y_label="HitRate@10",x_label="Incremental Steps",title="MovieLen_20M HitRate Allsteps")

# %%
 make_boxplot(ML20M_HitRDF,"HitRate@10",'Models','HitRate Range of Values for Each Model(ML_20M)')

# %% [markdown]
# ### mrr_20m

# %%
MRRDF_ML20M = pd.DataFrame(list(zip(Regpsi_MRR_20m,updted_MRR_20m,SVD_MRR_20m,VAE_MRR_20m,updtals_MRR_20m,RTals_MRR_20m,MPOP_mrr_20m,RRec_mrr_20m)), 
                           columns =['PSI_MRR','UpdtPSI_MRR','SVD_MRR','VAE_MRR','UpdtiALS_MRR','iALS_MRR','MPOP_MRR','RRec_MRR'])
MRRDF_ML20M
# Out:
#      PSI_MRR  UpdtPSI_MRR   SVD_MRR  ...  iALS_MRR  MPOP_MRR  RRec_MRR
# 0   0.019661     0.019750  0.021891  ...  0.015236  0.010980  0.000029
# 1   0.019737     0.019939  0.020462  ...  0.013069  0.008510  0.000136
# 2   0.020506     0.020556  0.020787  ...  0.013784  0.005916  0.000267
# 3   0.024115     0.023973  0.026738  ...  0.015161  0.016412  0.000000
# 4   0.022424     0.022273  0.023202  ...  0.013493  0.021320  0.000063
# 5   0.018706     0.018741  0.019234  ...  0.010798  0.012430  0.000145
# 6   0.015411     0.015228  0.015943  ...  0.011916  0.027296  0.000510
# 7   0.020189     0.020376  0.020867  ...  0.013365  0.009585  0.000053
# 8   0.024576     0.024525  0.025518  ...  0.016248  0.011028  0.000107
# 9   0.020357     0.020789  0.021960  ...  0.014866  0.010724  0.000293
# 10  0.023035     0.023081  0.024627  ...  0.015100  0.010729  0.000000
# 11  0.019458     0.019634  0.020163  ...  0.011921  0.008994  0.000046
# 12  0.025305     0.025079  0.027391  ...  0.016177  0.007529  0.000036
# 13  0.021488     0.021992  0.023731  ...  0.014580  0.012127  0.000180
# 14  0.026158     0.025983  0.026870  ...  0.011589  0.009542  0.000534
#
# [15 rows x 8 columns]

# %%
makeplot(AllSteps_15,MRRDF_ML20M,y_label="MRR@10",x_label="Incremental Steps",title="ML_20M MRR Allsteps")

# %%
make_boxplot(MRRDF_ML20M,"MRR@10",'Models','MRR Range of Values for Each Model(ML_20M)')

# %% [markdown]
# ### cov_20m

# %%
MLDF_20Mcov_DF = pd.DataFrame(list(zip(RegPSI_Cov_20m,updt_COV_20m,svd_cov_20m,VAE_cov_20m,updtals_Cov_20m,RTals_Cov_20m,Mpop_cov_20m,RRec_cov_20m)), 
                              columns =['PSI_COV','UpdtPSI_COV','SVD_COV','VAE_COV','UpdtiALS_COV','iALS_COV','MPOP_COV','RRec_COV'])
MLDF_20Mcov_DF
# Out:
#      PSI_COV  UpdtPSI_COV   SVD_COV  ...  iALS_COV  MPOP_COV  RRec_COV
# 0   0.042326     0.042278  0.043292  ...  0.118147  0.000483       1.0
# 1   0.042375     0.042326  0.043147  ...  0.118098  0.000483       1.0
# 2   0.042326     0.042278  0.043243  ...  0.118147  0.000483       1.0
# 3   0.042423     0.042278  0.043243  ...  0.118243  0.000483       1.0
# 4   0.042568     0.042133  0.043678  ...  0.118195  0.000483       1.0
# 5   0.042519     0.042181  0.043822  ...  0.118340  0.000483       1.0
# 6   0.042664     0.042471  0.044112  ...  0.118436  0.000483       1.0
# 7   0.042809     0.042471  0.044208  ...  0.118533  0.000483       1.0
# 8   0.042761     0.042519  0.044112  ...  0.118678  0.000483       1.0
# 9   0.042905     0.042471  0.044402  ...  0.118871  0.000483       1.0
# 10  0.042857     0.042471  0.044788  ...  0.118967  0.000483       1.0
# 11  0.043098     0.041988  0.045077  ...  0.118822  0.000483       1.0
# 12  0.043243     0.042085  0.045270  ...  0.119015  0.000483       1.0
# 13  0.043340     0.042085  0.045270  ...  0.119160  0.000483       1.0
# 14  0.042905     0.042181  0.044643  ...  0.119353  0.000483       1.0
#
# [15 rows x 8 columns]

# %%
cov_list  = [RegPSI_Cov_20m,updt_COV_20m,svd_cov_20m,VAE_cov_20m,updtals_Cov_20m,RTals_Cov_20m,Mpop_cov_20m,RRec_cov_20m]
label_list= [ 'PSI',      'Updt_PSI',    'SVD',       'VAE',      'Updt_iALS',    'iALS',       'Most_POP',   'Rand_Rec']
num_list = list(range(0,8))

plot_overlapping(cov_list,label_list,num_list,title="ML_20M Coverage values for Allsteps",
                 x_label="Incremental Steps",y_label="Coverage",size=(12,8),n=16)

# %%
makeplot(AllSteps_15,MLDF_20Mcov_DF,y_label="Coverage",x_label="Incremental Steps",title="ML_20M Coverage values for Allsteps")

# %%
make_boxplot(MLDF_20Mcov_DF,"Coverage",'Models','Coverage Range of Values for Each Model(ML_20M)')

# %% [markdown]
# ###Corr_20m

# %%
MLDF20M_CORR_DF = pd.DataFrame(list(zip(RegPSICorr_20m,updtCorr_20m,svd_corr_20m,VAE_corr_20m,updtiALSCorr_20m,RTiALSCorr_20m,Mpop_corr_20m,RRec_corr_20m)), 
                      columns =['PSI_Stby','UpdtedPSI_Stby','SVD_Stby','VAE_Stby','updt_iALS_Stby','iALS_Stby','MPOP_Stby','RRec_Stby'])
MLDF20M_CORR_DF
# Out:
#     PSI_Stby  UpdtedPSI_Stby  SVD_Stby  ...  iALS_Stby  MPOP_Stby  RRec_Stby
# 0   0.985505        0.986997  0.957942  ...   0.998789   0.881468   0.000149
# 1   0.986102        0.986899  0.965365  ...   0.999111   0.394352   0.000147
# 2   0.985238        0.986595  0.964228  ...   0.998967   0.470172   0.000163
# 3   0.985730        0.986736  0.960811  ...   0.999002   0.393825   0.000154
# 4   0.986202        0.987091  0.953990  ...   0.999072   0.441461   0.000143
# 5   0.986672        0.987394  0.959917  ...   0.999023   0.450953   0.000150
# 6   0.985409        0.986138  0.956695  ...   0.999153   0.438511   0.000158
# 7   0.984704        0.984788  0.951355  ...   0.999275   0.655490   0.000157
# 8   0.985241        0.985949  0.952474  ...   0.999061   0.763469   0.000145
# 9   0.985220        0.985750  0.954935  ...   0.998978   0.700104   0.000165
# 10  0.985830        0.986289  0.957097  ...   0.999139   0.770873   0.000153
# 11  0.985081        0.986179  0.956043  ...   0.998857   0.551934   0.000141
# 12  0.986148        0.986990  0.960663  ...   0.998916   0.402166   0.000146
# 13  0.986377        0.986713  0.963904  ...   0.999253   0.570927   0.000150
#
# [14 rows x 8 columns]

# %%
AllSteps_14 = list(range(1,15))
print(len(AllSteps_14))     
makeplot(AllSteps_14,MLDF20M_CORR_DF,y_label="Stability",x_label="Incremental Steps",title="ML_20M Stability values for Allsteps")
# Out:
# 14

# %%
##Plot for Overlapping Results
corr_list20M = [RegPSICorr_20m, updtCorr_20m, svd_corr_20m, VAE_corr_20m, updtiALSCorr_20m, RTiALSCorr_20m, Mpop_corr_20m, RRec_corr_20m]
label_list   = [    'PSI',     'Updt_PSI',      'SVD',        'VAE',       'Updt_iALS',        'iALS',        'Most_POP',    'Rand_Rec']
num_list = list(range(0,8))
plot_overlapping(corr_list20M,label_list,num_list,title="ML_20M Stability values for Allsteps",
                 x_label="Incremental Steps",y_label="Stability",size=(12,8),n=15)

# %%
make_boxplot(MLDF20M_CORR_DF,"Stability",'Models','Stability Range of Values for Each Model(ML_20M)')
